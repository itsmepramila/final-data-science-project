# %%
import pandas as pd

# %%
df=pd.read_csv("hr.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project
# 0                    0.24             0.79               2  \
# 1                    0.40             0.49               2
# 2                    0.45             0.45               2
# 3                    0.46             0.73               6
# 4                    0.14             0.54               5
# ...                   ...              ...             ...
# 14999                0.71             0.66               5
# 15000                0.75             0.84               3
# 15001                0.32             0.41               3
# 15002                0.62             0.58               3
# 15003                0.81             0.94               3
#
#        average_montly_hours  time_spend_company  Work_accident left
# 0                       175                   5              0    0  \
# 1                       155                   3              0    1
# 2                       154                   3              1    1
# 3                       256                   4              0    0
# 4                       275                   4              1    0
# ...                     ...                 ...            ...  ...
# 14999                   187                   2              0    0
# 15000                   145                   3              1    0
# 15001                   138                   3              1    0
# 15002                   148                   2              1    0
# 15003                   225                   4              0    0
#
#        promotion_last_5years   Department  salary   age
# 0                          0           IT     low   NaN
# 1                          0           hr  medium  27.0
# 2                          0      support  medium   NaN
# 3                          0  product_mng    high   NaN
# 4                          0        sales    high   NaN
# ...                      ...          ...     ...   ...
# 14999                      0        sales  medium   NaN
# 15000                      0      support     low   NaN
# 15001                      0    technical  medium  29.0
# 15002                      0    technical     low   NaN
# 15003                      0           hr  medium   NaN
#
# [15004 rows x 11 columns]

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours
# 0                0.24             0.79               2                   175  \
# 1                0.40             0.49               2                   155
# 2                0.45             0.45               2                   154
# 3                0.46             0.73               6                   256
# 4                0.14             0.54               5                   275
#
#    time_spend_company  Work_accident left  promotion_last_5years   Department
# 0                   5              0    0                      0           IT  \
# 1                   3              0    1                      0           hr
# 2                   3              1    1                      0      support
# 3                   4              0    0                      0  product_mng
# 4                   4              1    0                      0        sales
#
#    salary   age
# 0     low   NaN
# 1  medium  27.0
# 2  medium   NaN
# 3    high   NaN
# 4    high   NaN

# %%
df.shape
# Out:
# (15004, 11)

# %%
df.isnull()
# Out:
#        satisfaction_level  last_evaluation  number_project
# 0                   False            False           False  \
# 1                   False            False           False
# 2                   False            False           False
# 3                   False            False           False
# 4                   False            False           False
# ...                   ...              ...             ...
# 14999               False            False           False
# 15000               False            False           False
# 15001               False            False           False
# 15002               False            False           False
# 15003               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident   left
# 0                     False               False          False  False  \
# 1                     False               False          False  False
# 2                     False               False          False  False
# 3                     False               False          False  False
# 4                     False               False          False  False
# ...                     ...                 ...            ...    ...
# 14999                 False               False          False  False
# 15000                 False               False          False  False
# 15001                 False               False          False  False
# 15002                 False               False          False  False
# 15003                 False               False          False  False
#
#        promotion_last_5years  Department  salary    age
# 0                      False       False   False   True
# 1                      False       False   False  False
# 2                      False       False   False   True
# 3                      False       False   False   True
# 4                      False       False   False   True
# ...                      ...         ...     ...    ...
# 14999                  False       False   False   True
# 15000                  False       False   False   True
# 15001                  False       False   False  False
# 15002                  False       False   False   True
# 15003                  False       False   False   True
#
# [15004 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# satisfaction_level           0
# last_evaluation              0
# number_project               0
# average_montly_hours         0
# time_spend_company           0
# Work_accident                0
# left                         0
# promotion_last_5years        0
# Department                   0
# salary                      29
# age                      11924
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 11953

# %% [markdown]
# # filling null values

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,3))
sns.heatmap(df.isna().transpose())
# Out:
# <Axes: >

# %% [markdown]
# # handling missing data

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project
# 1                    0.40             0.49               2  \
# 9                    0.42             0.52               2
# 10                   0.11             0.88               7
# 17                   0.73             0.55               4
# 19                   0.61             0.98               2
# ...                   ...              ...             ...
# 14985                0.66             0.77               2
# 14989                0.79             0.87               5
# 14991                0.10             0.82               6
# 14993                0.98             0.70               3
# 15001                0.32             0.41               3
#
#        average_montly_hours  time_spend_company  Work_accident left
# 1                       155                   3              0    1  \
# 9                       141                   3              1    1
# 10                      272                   4              0    1
# 17                      267                   3              0    0
# 19                      238                   4              0    0
# ...                     ...                 ...            ...  ...
# 14985                   171                   2              0    0
# 14989                   261                   5              0    1
# 14991                   266                   4              0    1
# 14993                   153                  10              0    0
# 15001                   138                   3              1    0
#
#        promotion_last_5years  Department  salary   age
# 1                          0          hr  medium  27.0
# 9                          0       sales  medium  25.0
# 10                         0       sales  medium  27.0
# 17                         0       sales     low  25.0
# 19                         0     support  medium  28.0
# ...                      ...         ...     ...   ...
# 14985                      0   technical  medium  26.0
# 14989                      0       sales     low  25.0
# 14991                      0          IT     low  29.0
# 14993                      0  management    high  28.0
# 15001                      0   technical  medium  29.0
#
# [3074 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# age                      0
# dtype: int64

# %%
df.head()
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours
# 1                 0.40             0.49               2                   155  \
# 9                 0.42             0.52               2                   141
# 10                0.11             0.88               7                   272
# 17                0.73             0.55               4                   267
# 19                0.61             0.98               2                   238
#
#     time_spend_company  Work_accident left  promotion_last_5years Department
# 1                    3              0    1                      0         hr  \
# 9                    3              1    1                      0      sales
# 10                   4              0    1                      0      sales
# 17                   3              0    0                      0      sales
# 19                   4              0    0                      0    support
#
#     salary   age
# 1   medium  27.0
# 9   medium  25.0
# 10  medium  27.0
# 17     low  25.0
# 19  medium  28.0
